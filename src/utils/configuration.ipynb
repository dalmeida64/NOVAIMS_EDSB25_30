# %%
import re

# %%
raw_path = "../../Data/raw"
silver_path = "../../Data/silver"

# %%
def to_snake_case(s: str) -> str:
    s = s.strip("'\"").strip()
    s = re.sub(r'[\s\-\t]+', '_', s)
    s = re.sub(r'[^0-9a-zA-Z_]', '', s)
    return s.lower()

def test():
    pass
