# %%
# !pip install polars
# Out:
# Requirement already satisfied: polars in c:\users\danie\anaconda3\lib\site-packages (1.34.0)
# Requirement already satisfied: polars-runtime-32==1.34.0 in c:\users\danie\anaconda3\lib\site-packages (from polars) (1.34.0)

# %%
# %run ../utils/configuration.ipynb

# %%
import polars as pl
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
import pandas as pd

# %%
pdf = pd.read_excel(f"{raw_path}/Telco_customer_churn_location.xlsx")
df = pl.from_pandas(pdf)

# %%
print(df.head(3))
# Out:
# shape: (3, 9)
# ┌────────────┬───────┬────────────┬────────────┬───┬──────────┬────────────┬───────────┬───────────┐
# │ Customer   ┆ Count ┆ Country    ┆ State      ┆ … ┆ Zip Code ┆ Lat Long   ┆ Latitude  ┆ Longitude │
# │ ID         ┆ ---   ┆ ---        ┆ ---        ┆   ┆ ---      ┆ ---        ┆ ---       ┆ ---       │
# │ ---        ┆ i64   ┆ str        ┆ str        ┆   ┆ i64      ┆ str        ┆ f64       ┆ f64       │
# │ str        ┆       ┆            ┆            ┆   ┆          ┆            ┆           ┆           │
# ╞════════════╪═══════╪════════════╪════════════╪═══╪══════════╪════════════╪═══════════╪═══════════╡
# │ 8779-QRDMV ┆ 1     ┆ United     ┆ California ┆ … ┆ 90022    ┆ 34.02381,  ┆ 34.02381  ┆ -118.1565 │
# │            ┆       ┆ States     ┆            ┆   ┆          ┆ -118.15658 ┆           ┆ 82        │
# │            ┆       ┆            ┆            ┆   ┆          ┆ 2          ┆           ┆           │
# │ 7495-OOKFY ┆ 1     ┆ United     ┆ California ┆ … ┆ 90063    ┆ 34.044271, ┆ 34.044271 ┆ -118.1852 │
# │            ┆       ┆ States     ┆            ┆   ┆          ┆ -118.18523 ┆           ┆ 37        │
# │            ┆       ┆            ┆            ┆   ┆          ┆ 7          ┆           ┆           │
# │ 1658-BYGOY ┆ 1     ┆ United     ┆ California ┆ … ┆ 90065    ┆ 34.108833, ┆ 34.108833 ┆ -118.2297 │
# │            ┆       ┆ States     ┆            ┆   ┆          ┆ -118.22971 ┆           ┆ 15        │
# │            ┆       ┆            ┆            ┆   ┆          ┆ 5          ┆           ┆           │
# └────────────┴───────┴────────────┴────────────┴───┴──────────┴────────────┴───────────┴───────────┘

# %%
df
# Out:
# shape: (7_043, 9)
# ┌────────────┬───────┬────────────┬────────────┬───┬──────────┬────────────┬───────────┬───────────┐
# │ Customer   ┆ Count ┆ Country    ┆ State      ┆ … ┆ Zip Code ┆ Lat Long   ┆ Latitude  ┆ Longitude │
# │ ID         ┆ ---   ┆ ---        ┆ ---        ┆   ┆ ---      ┆ ---        ┆ ---       ┆ ---       │
# │ ---        ┆ i64   ┆ str        ┆ str        ┆   ┆ i64      ┆ str        ┆ f64       ┆ f64       │
# │ str        ┆       ┆            ┆            ┆   ┆          ┆            ┆           ┆           │
# ╞════════════╪═══════╪════════════╪════════════╪═══╪══════════╪════════════╪═══════════╪═══════════╡
# │ 8779-QRDMV ┆ 1     ┆ United     ┆ California ┆ … ┆ 90022    ┆ 34.02381,  ┆ 34.02381  ┆ -118.1565 │
# │            ┆       ┆ States     ┆            ┆   ┆          ┆ -118.15658 ┆           ┆ 82        │
# │            ┆       ┆            ┆            ┆   ┆          ┆ 2          ┆           ┆           │
# │ 7495-OOKFY ┆ 1     ┆ United     ┆ California ┆ … ┆ 90063    ┆ 34.044271, ┆ 34.044271 ┆ -118.1852 │
# │            ┆       ┆ States     ┆            ┆   ┆          ┆ -118.18523 ┆           ┆ 37        │
# │            ┆       ┆            ┆            ┆   ┆          ┆ 7          ┆           ┆           │
# │ 1658-BYGOY ┆ 1     ┆ United     ┆ California ┆ … ┆ 90065    ┆ 34.108833, ┆ 34.108833 ┆ -118.2297 │
# │            ┆       ┆ States     ┆            ┆   ┆          ┆ -118.22971 ┆           ┆ 15        │
# │            ┆       ┆            ┆            ┆   ┆          ┆ 5          ┆           ┆           │
# │ 4598-XLKNJ ┆ 1     ┆ United     ┆ California ┆ … ┆ 90303    ┆ 33.936291, ┆ 33.936291 ┆ -118.3326 │
# │            ┆       ┆ States     ┆            ┆   ┆          ┆ -118.33263 ┆           ┆ 39        │
# │            ┆       ┆            ┆            ┆   ┆          ┆ 9          ┆           ┆           │
# │ 4846-WHAFZ ┆ 1     ┆ United     ┆ California ┆ … ┆ 90602    ┆ 33.972119, ┆ 33.972119 ┆ -118.0201 │
# │            ┆       ┆ States     ┆            ┆   ┆          ┆ -118.02018 ┆           ┆ 88        │
# │            ┆       ┆            ┆            ┆   ┆          ┆ 8          ┆           ┆           │
# │ …          ┆ …     ┆ …          ┆ …          ┆ … ┆ …        ┆ …          ┆ …         ┆ …         │
# │ 2569-WGERO ┆ 1     ┆ United     ┆ California ┆ … ┆ 92285    ┆ 34.341737, ┆ 34.341737 ┆ -116.5394 │
# │            ┆       ┆ States     ┆            ┆   ┆          ┆ -116.53941 ┆           ┆ 16        │
# │            ┆       ┆            ┆            ┆   ┆          ┆ 6          ┆           ┆           │
# │ 6840-RESVB ┆ 1     ┆ United     ┆ California ┆ … ┆ 92301    ┆ 34.667815, ┆ 34.667815 ┆ -117.5361 │
# │            ┆       ┆ States     ┆            ┆   ┆          ┆ -117.53618 ┆           ┆ 83        │
# │            ┆       ┆            ┆            ┆   ┆          ┆ 3          ┆           ┆           │
# │ 2234-XADUH ┆ 1     ┆ United     ┆ California ┆ … ┆ 92304    ┆ 34.559882, ┆ 34.559882 ┆ -115.6371 │
# │            ┆       ┆ States     ┆            ┆   ┆          ┆ -115.63716 ┆           ┆ 64        │
# │            ┆       ┆            ┆            ┆   ┆          ┆ 4          ┆           ┆           │
# │ 4801-JZAZL ┆ 1     ┆ United     ┆ California ┆ … ┆ 92305    ┆ 34.1678,   ┆ 34.1678   ┆ -116.8643 │
# │            ┆       ┆ States     ┆            ┆   ┆          ┆ -116.86433 ┆           ┆ 3         │
# │ 3186-AJIEK ┆ 1     ┆ United     ┆ California ┆ … ┆ 92308    ┆ 34.424926, ┆ 34.424926 ┆ -117.1845 │
# │            ┆       ┆ States     ┆            ┆   ┆          ┆ -117.18450 ┆           ┆ 03        │
# │            ┆       ┆            ┆            ┆   ┆          ┆ 3          ┆           ┆           │
# └────────────┴───────┴────────────┴────────────┴───┴──────────┴────────────┴───────────┴───────────┘

# %%
for col in df.columns:
    print(f"{col}: {df[col].n_unique()} unique values")
# Out:
# Customer ID: 7043 unique values
# Count: 1 unique values
# Country: 1 unique values
# State: 1 unique values
# City: 1106 unique values
# Zip Code: 1626 unique values
# Lat Long: 1679 unique values
# Latitude: 1626 unique values
# Longitude: 1625 unique values

# %%
df = df.drop(["Count", "Country", "State"])
#Columns dropped due to only one unique value

# %%
# Check if 'Customer ID' follows the pattern: 4 numbers, a dash, and 5 letters using polars
import re
pattern = r"^\d{4}-[A-Za-z]{5}$"
mask = df.select(
    (pl.col('Customer ID').str.contains(pattern) == False).alias('invalid')
)['invalid']
invalid_ids = df.filter(mask)
if invalid_ids.height == 0:
    print("No invalid Customer IDs")
else:
    print(invalid_ids['Customer ID'])
# Out:
# No invalid Customer IDs

# %%
duplicates = df.filter(df.is_duplicated())
print(duplicates)
# Out:
# shape: (0, 6)
# ┌─────────────┬──────┬──────────┬──────────┬──────────┬───────────┐
# │ Customer ID ┆ City ┆ Zip Code ┆ Lat Long ┆ Latitude ┆ Longitude │
# │ ---         ┆ ---  ┆ ---      ┆ ---      ┆ ---      ┆ ---       │
# │ str         ┆ str  ┆ i64      ┆ str      ┆ f64      ┆ f64       │
# ╞═════════════╪══════╪══════════╪══════════╪══════════╪═══════════╡
# └─────────────┴──────┴──────────┴──────────┴──────────┴───────────┘

# %%
print([repr(c) for c in df.columns])
# Out:
# ["'Customer ID'", "'City'", "'Zip Code'", "'Lat Long'", "'Latitude'", "'Longitude'"]

# %%
df = df.rename({c: to_snake_case(c) for c in df.columns})

# %%
df.columns
# Out:
# ['customer_id', 'city', 'zip_code', 'lat_long', 'latitude', 'longitude']

# %%
df.write_parquet(f'{silver_path}/location.parquet')
