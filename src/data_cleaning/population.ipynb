# %%
# %pip install fastexcel
# %pip install polars

# %%
import polars as pl

# %%
df = pl.read_excel("../../Data/raw/Telco_customer_churn_population.xlsx")
df
# Out:
# shape: (1_671, 3)
# ┌──────┬──────────┬────────────┐
# │ ID   ┆ Zip Code ┆ Population │
# │ ---  ┆ ---      ┆ ---        │
# │ i64  ┆ i64      ┆ i64        │
# ╞══════╪══════════╪════════════╡
# │ 1    ┆ 90001    ┆ 54492      │
# │ 2    ┆ 90002    ┆ 44586      │
# │ 3    ┆ 90003    ┆ 58198      │
# │ 4    ┆ 90004    ┆ 67852      │
# │ 5    ┆ 90005    ┆ 43019      │
# │ …    ┆ …        ┆ …          │
# │ 1667 ┆ 96145    ┆ 4002       │
# │ 1668 ┆ 96146    ┆ 942        │
# │ 1669 ┆ 96148    ┆ 678        │
# │ 1670 ┆ 96150    ┆ 33038      │
# │ 1671 ┆ 96161    ┆ 15783      │
# └──────┴──────────┴────────────┘

# %%
df.count()
# Out:
# shape: (1, 3)
# ┌──────┬──────────┬────────────┐
# │ ID   ┆ Zip Code ┆ Population │
# │ ---  ┆ ---      ┆ ---        │
# │ u32  ┆ u32      ┆ u32        │
# ╞══════╪══════════╪════════════╡
# │ 1671 ┆ 1671     ┆ 1671       │
# └──────┴──────────┴────────────┘

# %%
df.columns
# Out:
# ['ID', 'Zip Code', 'Population']

# %%
df.describe()
# Out:
# shape: (9, 4)
# ┌────────────┬────────────┬─────────────┬──────────────┐
# │ statistic  ┆ ID         ┆ Zip Code    ┆ Population   │
# │ ---        ┆ ---        ┆ ---         ┆ ---          │
# │ str        ┆ f64        ┆ f64         ┆ f64          │
# ╞════════════╪════════════╪═════════════╪══════════════╡
# │ count      ┆ 1671.0     ┆ 1671.0      ┆ 1671.0       │
# │ null_count ┆ 0.0        ┆ 0.0         ┆ 0.0          │
# │ mean       ┆ 836.0      ┆ 93678.99222 ┆ 20276.384201 │
# │ std        ┆ 482.520466 ┆ 1817.763591 ┆ 20689.1173   │
# │ min        ┆ 1.0        ┆ 90001.0     ┆ 11.0         │
# │ 25%        ┆ 419.0      ┆ 92270.0     ┆ 1793.0       │
# │ 50%        ┆ 836.0      ┆ 93664.0     ┆ 14239.0      │
# │ 75%        ┆ 1254.0     ┆ 95409.0     ┆ 32984.0      │
# │ max        ┆ 1671.0     ┆ 96161.0     ┆ 105285.0     │
# └────────────┴────────────┴─────────────┴──────────────┘

# %%
df.group_by(pl.col('Zip Code')).len()
# Out:
# shape: (1_671, 2)
# ┌──────────┬─────┐
# │ Zip Code ┆ len │
# │ ---      ┆ --- │
# │ i64      ┆ u32 │
# ╞══════════╪═════╡
# │ 93204    ┆ 1   │
# │ 92284    ┆ 1   │
# │ 95970    ┆ 1   │
# │ 94511    ┆ 1   │
# │ 92025    ┆ 1   │
# │ …        ┆ …   │
# │ 93722    ┆ 1   │
# │ 93710    ┆ 1   │
# │ 96062    ┆ 1   │
# │ 95547    ┆ 1   │
# │ 95949    ┆ 1   │
# └──────────┴─────┘

# %%
df.group_by(pl.col('Population')).len()
# Out:
# shape: (1_607, 2)
# ┌────────────┬─────┐
# │ Population ┆ len │
# │ ---        ┆ --- │
# │ i64        ┆ u32 │
# ╞════════════╪═════╡
# │ 13121      ┆ 1   │
# │ 3674       ┆ 1   │
# │ 13779      ┆ 1   │
# │ 41575      ┆ 1   │
# │ 155        ┆ 1   │
# │ …          ┆ …   │
# │ 11650      ┆ 1   │
# │ 56887      ┆ 1   │
# │ 8759       ┆ 1   │
# │ 53204      ┆ 1   │
# │ 17944      ┆ 1   │
# └────────────┴─────┘
