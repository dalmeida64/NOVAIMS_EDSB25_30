# %%
# %pip install fastexcel
# %pip install polars

# %%
# %run ../utils/configuration.ipynb

# %%
import polars as pl

# %%
df = pl.read_excel(f"{raw_path}/Telco_customer_churn_services.xlsx")
df
# Out:
# shape: (7_043, 30)
# ┌────────────┬───────┬─────────┬────────────┬───┬────────────┬────────────┬────────────┬───────────┐
# │ Customer   ┆ Count ┆ Quarter ┆ Referred a ┆ … ┆ Total      ┆ Total      ┆ Total Long ┆ Total     │
# │ ID         ┆ ---   ┆ ---     ┆ Friend     ┆   ┆ Refunds    ┆ Extra Data ┆ Distance   ┆ Revenue   │
# │ ---        ┆ i64   ┆ str     ┆ ---        ┆   ┆ ---        ┆ Charges    ┆ Charges    ┆ ---       │
# │ str        ┆       ┆         ┆ str        ┆   ┆ f64        ┆ ---        ┆ ---        ┆ f64       │
# │            ┆       ┆         ┆            ┆   ┆            ┆ i64        ┆ f64        ┆           │
# ╞════════════╪═══════╪═════════╪════════════╪═══╪════════════╪════════════╪════════════╪═══════════╡
# │ 8779-QRDMV ┆ 1     ┆ Q3      ┆ No         ┆ … ┆ 0.0        ┆ 20         ┆ 0.0        ┆ 59.65     │
# │ 7495-OOKFY ┆ 1     ┆ Q3      ┆ Yes        ┆ … ┆ 0.0        ┆ 0          ┆ 390.8      ┆ 1024.1    │
# ...

# %%
df.count()
# Out:
# shape: (1, 30)
# ┌────────────┬───────┬─────────┬────────────┬───┬────────────┬────────────┬────────────┬───────────┐
# │ Customer   ┆ Count ┆ Quarter ┆ Referred a ┆ … ┆ Total      ┆ Total      ┆ Total Long ┆ Total     │
# │ ID         ┆ ---   ┆ ---     ┆ Friend     ┆   ┆ Refunds    ┆ Extra Data ┆ Distance   ┆ Revenue   │
# │ ---        ┆ u32   ┆ u32     ┆ ---        ┆   ┆ ---        ┆ Charges    ┆ Charges    ┆ ---       │
# │ u32        ┆       ┆         ┆ u32        ┆   ┆ u32        ┆ ---        ┆ ---        ┆ u32       │
# │            ┆       ┆         ┆            ┆   ┆            ┆ u32        ┆ u32        ┆           │
# ╞════════════╪═══════╪═════════╪════════════╪═══╪════════════╪════════════╪════════════╪═══════════╡
# │ 7043       ┆ 7043  ┆ 7043    ┆ 7043       ┆ … ┆ 7043       ┆ 7043       ┆ 7043       ┆ 7043      │
# └────────────┴───────┴─────────┴────────────┴───┴────────────┴────────────┴────────────┴───────────┘

# %%
df.columns
# Out:
# ['Customer ID',
#  'Count',
#  'Quarter',
#  'Referred a Friend',
#  'Number of Referrals',
#  'Tenure in Months',
#  'Offer',
#  'Phone Service',
#  'Avg Monthly Long Distance Charges',
#  'Multiple Lines',
#  'Internet Service',
#  'Internet Type',
#  'Avg Monthly GB Download',
#  'Online Security',
#  'Online Backup',
#  'Device Protection Plan',
#  'Premium Tech Support',
#  'Streaming TV',
#  'Streaming Movies',
#  'Streaming Music',
#  'Unlimited Data',
#  'Contract',
#  'Paperless Billing',
#  'Payment Method',
#  'Monthly Charge',
#  'Total Charges',
#  'Total Refunds',
#  'Total Extra Data Charges',
#  'Total Long Distance Charges',
#  'Total Revenue']

# %%
df.describe()
# Out:
# shape: (9, 31)
# ┌────────────┬────────────┬────────┬─────────┬───┬────────────┬────────────┬───────────┬───────────┐
# │ statistic  ┆ Customer   ┆ Count  ┆ Quarter ┆ … ┆ Total      ┆ Total      ┆ Total     ┆ Total     │
# │ ---        ┆ ID         ┆ ---    ┆ ---     ┆   ┆ Refunds    ┆ Extra Data ┆ Long      ┆ Revenue   │
# │ str        ┆ ---        ┆ f64    ┆ str     ┆   ┆ ---        ┆ Charges    ┆ Distance  ┆ ---       │
# │            ┆ str        ┆        ┆         ┆   ┆ f64        ┆ ---        ┆ Charges   ┆ f64       │
# │            ┆            ┆        ┆         ┆   ┆            ┆ f64        ┆ ---       ┆           │
# │            ┆            ┆        ┆         ┆   ┆            ┆            ┆ f64       ┆           │
# ╞════════════╪════════════╪════════╪═════════╪═══╪════════════╪════════════╪═══════════╪═══════════╡
# │ count      ┆ 7043       ┆ 7043.0 ┆ 7043    ┆ … ┆ 7043.0     ┆ 7043.0     ┆ 7043.0    ┆ 7043.0    │
# ...

# %%
df.group_by(pl.col('Customer ID')).len()
# Out:
# shape: (7_043, 2)
# ┌─────────────┬─────┐
# │ Customer ID ┆ len │
# │ ---         ┆ --- │
# │ str         ┆ u32 │
# ╞═════════════╪═════╡
# │ 9708-KFDBY  ┆ 1   │
# │ 8885-QSQBX  ┆ 1   │
# │ 4137-JOPHL  ┆ 1   │
# │ 6813-GZQCG  ┆ 1   │
# │ 4501-VCPFK  ┆ 1   │
# │ …           ┆ …   │
# │ 6849-OYAMU  ┆ 1   │
# │ 2322-VCZHZ  ┆ 1   │
# │ 7691-KGKGP  ┆ 1   │
# │ 5982-PSMKW  ┆ 1   │
# │ 4877-TSOFF  ┆ 1   │
# └─────────────┴─────┘

# %%
df.group_by(pl.col('Count')).len()
# Out:
# shape: (1, 2)
# ┌───────┬──────┐
# │ Count ┆ len  │
# │ ---   ┆ ---  │
# │ i64   ┆ u32  │
# ╞═══════╪══════╡
# │ 1     ┆ 7043 │
# └───────┴──────┘

# %%
df.group_by(pl.col('Quarter')).len()
# Out:
# shape: (1, 2)
# ┌─────────┬──────┐
# │ Quarter ┆ len  │
# │ ---     ┆ ---  │
# │ str     ┆ u32  │
# ╞═════════╪══════╡
# │ Q3      ┆ 7043 │
# └─────────┴──────┘

# %%
df.group_by(pl.col('Referred a Friend')).len()
# Out:
# shape: (2, 2)
# ┌───────────────────┬──────┐
# │ Referred a Friend ┆ len  │
# │ ---               ┆ ---  │
# │ str               ┆ u32  │
# ╞═══════════════════╪══════╡
# │ Yes               ┆ 3222 │
# │ No                ┆ 3821 │
# └───────────────────┴──────┘

# %%
df.group_by(pl.col('Number of Referrals')).len()
# Out:
# shape: (12, 2)
# ┌─────────────────────┬──────┐
# │ Number of Referrals ┆ len  │
# │ ---                 ┆ ---  │
# │ i64                 ┆ u32  │
# ╞═════════════════════╪══════╡
# │ 10                  ┆ 223  │
# │ 0                   ┆ 3821 │
# │ 5                   ┆ 264  │
# │ 6                   ┆ 221  │
# │ 8                   ┆ 213  │
# │ …                   ┆ …    │
# │ 7                   ┆ 248  │
# │ 9                   ┆ 238  │
# │ 2                   ┆ 236  │
# │ 4                   ┆ 236  │
# │ 3                   ┆ 255  │
# └─────────────────────┴──────┘

# %%
df.group_by(pl.col('Tenure in Months')).len()
# Out:
# shape: (72, 2)
# ┌──────────────────┬─────┐
# │ Tenure in Months ┆ len │
# │ ---              ┆ --- │
# │ i64              ┆ u32 │
# ╞══════════════════╪═════╡
# │ 6                ┆ 110 │
# │ 18               ┆ 97  │
# │ 3                ┆ 200 │
# │ 15               ┆ 99  │
# │ 21               ┆ 63  │
# │ …                ┆ …   │
# │ 62               ┆ 70  │
# │ 65               ┆ 76  │
# │ 59               ┆ 60  │
# │ 71               ┆ 170 │
# │ 68               ┆ 100 │
# └──────────────────┴─────┘

# %%
df.group_by(pl.col('Offer')).len()
# Out:
# shape: (6, 2)
# ┌─────────┬──────┐
# │ Offer   ┆ len  │
# │ ---     ┆ ---  │
# │ str     ┆ u32  │
# ╞═════════╪══════╡
# │ None    ┆ 3877 │
# │ Offer A ┆ 520  │
# │ Offer E ┆ 805  │
# │ Offer C ┆ 415  │
# │ Offer B ┆ 824  │
# │ Offer D ┆ 602  │
# └─────────┴──────┘

# %%
df.group_by(pl.col('Phone Service')).len()
# Out:
# shape: (2, 2)
# ┌───────────────┬──────┐
# │ Phone Service ┆ len  │
# │ ---           ┆ ---  │
# │ str           ┆ u32  │
# ╞═══════════════╪══════╡
# │ No            ┆ 682  │
# │ Yes           ┆ 6361 │
# └───────────────┴──────┘

# %%
df.group_by(pl.col('Avg Monthly Long Distance Charges')).len()
# Out:
# shape: (3_584, 2)
# ┌─────────────────────────────────┬─────┐
# │ Avg Monthly Long Distance Char… ┆ len │
# │ ---                             ┆ --- │
# │ f64                             ┆ u32 │
# ╞═════════════════════════════════╪═════╡
# │ 7.74                            ┆ 2   │
# │ 23.95                           ┆ 3   │
# │ 17.28                           ┆ 2   │
# │ 2.52                            ┆ 2   │
# │ 43.83                           ┆ 1   │
# │ …                               ┆ …   │
# │ 14.11                           ┆ 1   │
# │ 7.96                            ┆ 2   │
# │ 29.49                           ┆ 1   │
# │ 25.82                           ┆ 2   │
# │ 27.69                           ┆ 3   │
# └─────────────────────────────────┴─────┘

# %%
df.group_by(pl.col('Multiple Lines')).len()
# Out:
# shape: (2, 2)
# ┌────────────────┬──────┐
# │ Multiple Lines ┆ len  │
# │ ---            ┆ ---  │
# │ str            ┆ u32  │
# ╞════════════════╪══════╡
# │ No             ┆ 4072 │
# │ Yes            ┆ 2971 │
# └────────────────┴──────┘

# %%
df.group_by(pl.col('Internet Service')).len()
# Out:
# shape: (2, 2)
# ┌──────────────────┬──────┐
# │ Internet Service ┆ len  │
# │ ---              ┆ ---  │
# │ str              ┆ u32  │
# ╞══════════════════╪══════╡
# │ Yes              ┆ 5517 │
# │ No               ┆ 1526 │
# └──────────────────┴──────┘

# %%
df.group_by(pl.col('Internet Type')).len()
# Out:
# shape: (4, 2)
# ┌───────────────┬──────┐
# │ Internet Type ┆ len  │
# │ ---           ┆ ---  │
# │ str           ┆ u32  │
# ╞═══════════════╪══════╡
# │ Cable         ┆ 830  │
# │ DSL           ┆ 1652 │
# │ Fiber Optic   ┆ 3035 │
# │ None          ┆ 1526 │
# └───────────────┴──────┘

# %%
df.group_by(pl.col('Avg Monthly GB Download')).len()
# Out:
# shape: (50, 2)
# ┌─────────────────────────┬─────┐
# │ Avg Monthly GB Download ┆ len │
# │ ---                     ┆ --- │
# │ i64                     ┆ u32 │
# ╞═════════════════════════╪═════╡
# │ 21                      ┆ 171 │
# │ 75                      ┆ 15  │
# │ 73                      ┆ 81  │
# │ 56                      ┆ 16  │
# │ 22                      ┆ 172 │
# │ …                       ┆ …   │
# │ 29                      ┆ 138 │
# │ 18                      ┆ 164 │
# │ 3                       ┆ 130 │
# │ 13                      ┆ 164 │
# │ 58                      ┆ 45  │
# └─────────────────────────┴─────┘

# %%
df.group_by(pl.col('Online Security')).len()
# Out:
# shape: (2, 2)
# ┌─────────────────┬──────┐
# │ Online Security ┆ len  │
# │ ---             ┆ ---  │
# │ str             ┆ u32  │
# ╞═════════════════╪══════╡
# │ Yes             ┆ 2019 │
# │ No              ┆ 5024 │
# └─────────────────┴──────┘

# %%
df.group_by(pl.col('Online Backup')).len()
# Out:
# shape: (2, 2)
# ┌───────────────┬──────┐
# │ Online Backup ┆ len  │
# │ ---           ┆ ---  │
# │ str           ┆ u32  │
# ╞═══════════════╪══════╡
# │ Yes           ┆ 2429 │
# │ No            ┆ 4614 │
# └───────────────┴──────┘

# %%
df.group_by(pl.col('Device Protection Plan')).len()
# Out:
# shape: (2, 2)
# ┌────────────────────────┬──────┐
# │ Device Protection Plan ┆ len  │
# │ ---                    ┆ ---  │
# │ str                    ┆ u32  │
# ╞════════════════════════╪══════╡
# │ No                     ┆ 4621 │
# │ Yes                    ┆ 2422 │
# └────────────────────────┴──────┘

# %%
df.group_by(pl.col('Premium Tech Support')).len()
# Out:
# shape: (2, 2)
# ┌──────────────────────┬──────┐
# │ Premium Tech Support ┆ len  │
# │ ---                  ┆ ---  │
# │ str                  ┆ u32  │
# ╞══════════════════════╪══════╡
# │ No                   ┆ 4999 │
# │ Yes                  ┆ 2044 │
# └──────────────────────┴──────┘

# %%
df.group_by(pl.col('Streaming TV')).len()
# Out:
# shape: (2, 2)
# ┌──────────────┬──────┐
# │ Streaming TV ┆ len  │
# │ ---          ┆ ---  │
# │ str          ┆ u32  │
# ╞══════════════╪══════╡
# │ Yes          ┆ 2707 │
# │ No           ┆ 4336 │
# └──────────────┴──────┘

# %%
df.group_by(pl.col('Streaming Movies')).len()
# Out:
# shape: (2, 2)
# ┌──────────────────┬──────┐
# │ Streaming Movies ┆ len  │
# │ ---              ┆ ---  │
# │ str              ┆ u32  │
# ╞══════════════════╪══════╡
# │ Yes              ┆ 2732 │
# │ No               ┆ 4311 │
# └──────────────────┴──────┘

# %%
df.group_by(pl.col('Streaming Music')).len()
# Out:
# shape: (2, 2)
# ┌─────────────────┬──────┐
# │ Streaming Music ┆ len  │
# │ ---             ┆ ---  │
# │ str             ┆ u32  │
# ╞═════════════════╪══════╡
# │ No              ┆ 4555 │
# │ Yes             ┆ 2488 │
# └─────────────────┴──────┘

# %%
df.group_by(pl.col('Unlimited Data')).len()
# Out:
# shape: (2, 2)
# ┌────────────────┬──────┐
# │ Unlimited Data ┆ len  │
# │ ---            ┆ ---  │
# │ str            ┆ u32  │
# ╞════════════════╪══════╡
# │ No             ┆ 2298 │
# │ Yes            ┆ 4745 │
# └────────────────┴──────┘

# %%
df.group_by(pl.col('Contract')).len()
# Out:
# shape: (3, 2)
# ┌────────────────┬──────┐
# │ Contract       ┆ len  │
# │ ---            ┆ ---  │
# │ str            ┆ u32  │
# ╞════════════════╪══════╡
# │ One Year       ┆ 1550 │
# │ Two Year       ┆ 1883 │
# │ Month-to-Month ┆ 3610 │
# └────────────────┴──────┘

# %%
df.group_by(pl.col('Paperless Billing')).len()
# Out:
# shape: (2, 2)
# ┌───────────────────┬──────┐
# │ Paperless Billing ┆ len  │
# │ ---               ┆ ---  │
# │ str               ┆ u32  │
# ╞═══════════════════╪══════╡
# │ Yes               ┆ 4171 │
# │ No                ┆ 2872 │
# └───────────────────┴──────┘

# %%
df.group_by(pl.col('Payment Method')).len()
# Out:
# shape: (3, 2)
# ┌─────────────────┬──────┐
# │ Payment Method  ┆ len  │
# │ ---             ┆ ---  │
# │ str             ┆ u32  │
# ╞═════════════════╪══════╡
# │ Credit Card     ┆ 2749 │
# │ Mailed Check    ┆ 385  │
# │ Bank Withdrawal ┆ 3909 │
# └─────────────────┴──────┘

# %%
df.group_by(pl.col('Monthly Charge')).len()
# Out:
# shape: (1_585, 2)
# ┌────────────────┬─────┐
# │ Monthly Charge ┆ len │
# │ ---            ┆ --- │
# │ f64            ┆ u32 │
# ╞════════════════╪═════╡
# │ 69.05          ┆ 7   │
# │ 92.05          ┆ 1   │
# │ 50.4           ┆ 4   │
# │ 103.05         ┆ 3   │
# │ 108.1          ┆ 5   │
# │ …              ┆ …   │
# │ 29.6           ┆ 3   │
# │ 114.05         ┆ 2   │
# │ 23.85          ┆ 2   │
# │ 96.55          ┆ 5   │
# │ 73.1           ┆ 1   │
# └────────────────┴─────┘

# %%
df.group_by(pl.col('Total Charges')).len()
# Out:
# shape: (6_540, 2)
# ┌───────────────┬─────┐
# │ Total Charges ┆ len │
# │ ---           ┆ --- │
# │ f64           ┆ u32 │
# ╞═══════════════╪═════╡
# │ 978.0         ┆ 1   │
# │ 1956.4        ┆ 1   │
# │ 1888.45       ┆ 1   │
# │ 1071.6        ┆ 1   │
# │ 450.4         ┆ 1   │
# │ …             ┆ …   │
# │ 454.0         ┆ 1   │
# │ 222.65        ┆ 1   │
# │ 5705.05       ┆ 1   │
# │ 4720.0        ┆ 1   │
# │ 1165.6        ┆ 1   │
# └───────────────┴─────┘

# %%
df.group_by(pl.col('Total Refunds')).len()
# Out:
# shape: (500, 2)
# ┌───────────────┬─────┐
# │ Total Refunds ┆ len │
# │ ---           ┆ --- │
# │ f64           ┆ u32 │
# ╞═══════════════╪═════╡
# │ 46.67         ┆ 1   │
# │ 45.07         ┆ 1   │
# │ 8.13          ┆ 1   │
# │ 31.58         ┆ 1   │
# │ 40.95         ┆ 1   │
# │ …             ┆ …   │
# │ 32.59         ┆ 1   │
# │ 23.39         ┆ 1   │
# │ 19.63         ┆ 1   │
# │ 4.48          ┆ 1   │
# │ 19.16         ┆ 1   │
# └───────────────┴─────┘

# %%
df.group_by(pl.col('Total Extra Data Charges')).len()
# Out:
# shape: (16, 2)
# ┌──────────────────────────┬─────┐
# │ Total Extra Data Charges ┆ len │
# │ ---                      ┆ --- │
# │ i64                      ┆ u32 │
# ╞══════════════════════════╪═════╡
# │ 10                       ┆ 138 │
# │ 30                       ┆ 58  │
# │ 120                      ┆ 28  │
# │ 130                      ┆ 40  │
# │ 110                      ┆ 32  │
# │ …                        ┆ …   │
# │ 90                       ┆ 35  │
# │ 50                       ┆ 43  │
# │ 150                      ┆ 42  │
# │ 100                      ┆ 44  │
# │ 70                       ┆ 34  │
# └──────────────────────────┴─────┘

# %%
df.group_by(pl.col('Total Long Distance Charges')).len()
# Out:
# shape: (6_110, 2)
# ┌─────────────────────────────┬─────┐
# │ Total Long Distance Charges ┆ len │
# │ ---                         ┆ --- │
# │ f64                         ┆ u32 │
# ╞═════════════════════════════╪═════╡
# │ 2021.37                     ┆ 1   │
# │ 778.87                      ┆ 1   │
# │ 2424.96                     ┆ 1   │
# │ 713.55                      ┆ 1   │
# │ 791.01                      ┆ 1   │
# │ …                           ┆ …   │
# │ 757.77                      ┆ 1   │
# │ 18.96                       ┆ 1   │
# │ 548.99                      ┆ 1   │
# │ 72.54                       ┆ 1   │
# │ 316.72                      ┆ 1   │
# └─────────────────────────────┴─────┘

# %%
df.group_by(pl.col('Total Revenue')).len()
# Out:
# shape: (6_996, 2)
# ┌───────────────┬─────┐
# │ Total Revenue ┆ len │
# │ ---           ┆ --- │
# │ f64           ┆ u32 │
# ╞═══════════════╪═════╡
# │ 7281.64       ┆ 1   │
# │ 467.31        ┆ 1   │
# │ 1089.23       ┆ 1   │
# │ 1212.0        ┆ 1   │
# │ 6627.8        ┆ 1   │
# │ …             ┆ …   │
# │ 5330.0        ┆ 1   │
# │ 752.89        ┆ 1   │
# │ 2999.8        ┆ 1   │
# │ 38.78         ┆ 1   │
# │ 3669.72       ┆ 1   │
# └───────────────┴─────┘

# %% [markdown]
# Both Count and Quarter have allways the same result

# %%
# Drop de múltiplas colunas
df = df.drop(["Count", "Quarter"])
df
# Out:
# shape: (7_043, 28)
# ┌───────────┬───────────┬───────────┬───────────┬───┬───────────┬───────────┬───────────┬──────────┐
# │ Customer  ┆ Referred  ┆ Number of ┆ Tenure in ┆ … ┆ Total     ┆ Total     ┆ Total     ┆ Total    │
# │ ID        ┆ a Friend  ┆ Referrals ┆ Months    ┆   ┆ Refunds   ┆ Extra     ┆ Long      ┆ Revenue  │
# │ ---       ┆ ---       ┆ ---       ┆ ---       ┆   ┆ ---       ┆ Data      ┆ Distance  ┆ ---      │
# │ str       ┆ str       ┆ i64       ┆ i64       ┆   ┆ f64       ┆ Charges   ┆ Charges   ┆ f64      │
# │           ┆           ┆           ┆           ┆   ┆           ┆ ---       ┆ ---       ┆          │
# │           ┆           ┆           ┆           ┆   ┆           ┆ i64       ┆ f64       ┆          │
# ╞═══════════╪═══════════╪═══════════╪═══════════╪═══╪═══════════╪═══════════╪═══════════╪══════════╡
# │ 8779-QRDM ┆ No        ┆ 0         ┆ 1         ┆ … ┆ 0.0       ┆ 20        ┆ 0.0       ┆ 59.65    │
# ...

# %%
df.columns
# Out:
# ['Customer ID',
#  'Referred a Friend',
#  'Number of Referrals',
#  'Tenure in Months',
#  'Offer',
#  'Phone Service',
#  'Avg Monthly Long Distance Charges',
#  'Multiple Lines',
#  'Internet Service',
#  'Internet Type',
#  'Avg Monthly GB Download',
#  'Online Security',
#  'Online Backup',
#  'Device Protection Plan',
#  'Premium Tech Support',
#  'Streaming TV',
#  'Streaming Movies',
#  'Streaming Music',
#  'Unlimited Data',
#  'Contract',
#  'Paperless Billing',
#  'Payment Method',
#  'Monthly Charge',
#  'Total Charges',
#  'Total Refunds',
#  'Total Extra Data Charges',
#  'Total Long Distance Charges',
#  'Total Revenue']

# %%
df = df.rename({c: to_snake_case(c) for c in df.columns})

# %%
df.columns
# Out:
# ['customer_id',
#  'referred_a_friend',
#  'number_of_referrals',
#  'tenure_in_months',
#  'offer',
#  'phone_service',
#  'avg_monthly_long_distance_charges',
#  'multiple_lines',
#  'internet_service',
#  'internet_type',
#  'avg_monthly_gb_download',
#  'online_security',
#  'online_backup',
#  'device_protection_plan',
#  'premium_tech_support',
#  'streaming_tv',
#  'streaming_movies',
#  'streaming_music',
#  'unlimited_data',
#  'contract',
#  'paperless_billing',
#  'payment_method',
#  'monthly_charge',
#  'total_charges',
#  'total_refunds',
#  'total_extra_data_charges',
#  'total_long_distance_charges',
#  'total_revenue']

# %%
df.write_parquet(f'{silver_path}/service.parquet')
