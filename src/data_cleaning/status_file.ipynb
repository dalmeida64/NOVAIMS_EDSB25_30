# %%
# %pip install fastexcel
# %pip install polars
# Out:
# Collecting fastexcel
#   Downloading fastexcel-0.16.0-cp39-abi3-win_amd64.whl.metadata (7.2 kB)
# Downloading fastexcel-0.16.0-cp39-abi3-win_amd64.whl (2.8 MB)
#    ---------------------------------------- 0.0/2.8 MB ? eta -:--:--
#    ------------------------------------- -- 2.6/2.8 MB 15.1 MB/s eta 0:00:01
#    ---------------------------------------- 2.8/2.8 MB 13.7 MB/s  0:00:00
# Installing collected packages: fastexcel
# Successfully installed fastexcel-0.16.0
# Note: you may need to restart the kernel to use updated packages.

# %%
import polars as pl

# %%
df = pl.read_excel("../../Data/raw/Telco_customer_churn_status.xlsx")

# %%
df.head(10)
# Out:
# shape: (10, 11)
# ┌─────────────┬───────┬─────────┬─────────────┬───┬─────────────┬──────┬─────────────┬─────────────┐
# │ Customer ID ┆ Count ┆ Quarter ┆ Satisfactio ┆ … ┆ Churn Score ┆ CLTV ┆ Churn       ┆ Churn       │
# │ ---         ┆ ---   ┆ ---     ┆ n Score     ┆   ┆ ---         ┆ ---  ┆ Category    ┆ Reason      │
# │ str         ┆ i64   ┆ str     ┆ ---         ┆   ┆ i64         ┆ i64  ┆ ---         ┆ ---         │
# │             ┆       ┆         ┆ i64         ┆   ┆             ┆      ┆ str         ┆ str         │
# ╞═════════════╪═══════╪═════════╪═════════════╪═══╪═════════════╪══════╪═════════════╪═════════════╡
# │ 8779-QRDMV  ┆ 1     ┆ Q3      ┆ 3           ┆ … ┆ 91          ┆ 5433 ┆ Competitor  ┆ Competitor  │
# │             ┆       ┆         ┆             ┆   ┆             ┆      ┆             ┆ offered     │
# │             ┆       ┆         ┆             ┆   ┆             ┆      ┆             ┆ more data   │
# │ 7495-OOKFY  ┆ 1     ┆ Q3      ┆ 3           ┆ … ┆ 69          ┆ 5302 ┆ Competitor  ┆ Competitor  │
# │             ┆       ┆         ┆             ┆   ┆             ┆      ┆             ┆ made better │
# │             ┆       ┆         ┆             ┆   ┆             ┆      ┆             ┆ offer       │
# │ 1658-BYGOY  ┆ 1     ┆ Q3      ┆ 2           ┆ … ┆ 81          ┆ 3179 ┆ Competitor  ┆ Competitor  │
# │             ┆       ┆         ┆             ┆   ┆             ┆      ┆             ┆ made better │
# │             ┆       ┆         ┆             ┆   ┆             ┆      ┆             ┆ offer       │
# │ 4598-XLKNJ  ┆ 1     ┆ Q3      ┆ 2           ┆ … ┆ 88          ┆ 5337 ┆ Dissatisfac ┆ Limited     │
# │             ┆       ┆         ┆             ┆   ┆             ┆      ┆ tion        ┆ range of    │
# │             ┆       ┆         ┆             ┆   ┆             ┆      ┆             ┆ services    │
# │ 4846-WHAFZ  ┆ 1     ┆ Q3      ┆ 2           ┆ … ┆ 67          ┆ 2793 ┆ Price       ┆ Extra data  │
# │             ┆       ┆         ┆             ┆   ┆             ┆      ┆             ┆ charges     │
# │ 4412-YLTKF  ┆ 1     ┆ Q3      ┆ 1           ┆ … ┆ 95          ┆ 4638 ┆ Competitor  ┆ Competitor  │
# │             ┆       ┆         ┆             ┆   ┆             ┆      ┆             ┆ had better  │
# │             ┆       ┆         ┆             ┆   ┆             ┆      ┆             ┆ devices     │
# │ 0390-DCFDQ  ┆ 1     ┆ Q3      ┆ 2           ┆ … ┆ 76          ┆ 3964 ┆ Other       ┆ Don't know  │
# │ 3445-HXXGF  ┆ 1     ┆ Q3      ┆ 1           ┆ … ┆ 91          ┆ 5444 ┆ Dissatisfac ┆ Service dis │
# │             ┆       ┆         ┆             ┆   ┆             ┆      ┆ tion        ┆ satisfactio │
# │             ┆       ┆         ┆             ┆   ┆             ┆      ┆             ┆ n           │
# │ 2656-FMOKZ  ┆ 1     ┆ Q3      ┆ 2           ┆ … ┆ 91          ┆ 5717 ┆ Dissatisfac ┆ Limited     │
# │             ┆       ┆         ┆             ┆   ┆             ┆      ┆ tion        ┆ range of    │
# │             ┆       ┆         ┆             ┆   ┆             ┆      ┆             ┆ services    │
# │ 2070-FNEXE  ┆ 1     ┆ Q3      ┆ 2           ┆ … ┆ 81          ┆ 4419 ┆ Price       ┆ Lack of     │
# │             ┆       ┆         ┆             ┆   ┆             ┆      ┆             ┆ affordable  │
# │             ┆       ┆         ┆             ┆   ┆             ┆      ┆             ┆ download/up │
# │             ┆       ┆         ┆             ┆   ┆             ┆      ┆             ┆ …           │
# └─────────────┴───────┴─────────┴─────────────┴───┴─────────────┴──────┴─────────────┴─────────────┘

# %%
df.count()
# Out:
# shape: (1, 11)
# ┌─────────────┬───────┬─────────┬───────────────┬───┬─────────────┬──────┬──────────┬──────────────┐
# │ Customer ID ┆ Count ┆ Quarter ┆ Satisfaction  ┆ … ┆ Churn Score ┆ CLTV ┆ Churn    ┆ Churn Reason │
# │ ---         ┆ ---   ┆ ---     ┆ Score         ┆   ┆ ---         ┆ ---  ┆ Category ┆ ---          │
# │ u32         ┆ u32   ┆ u32     ┆ ---           ┆   ┆ u32         ┆ u32  ┆ ---      ┆ u32          │
# │             ┆       ┆         ┆ u32           ┆   ┆             ┆      ┆ u32      ┆              │
# ╞═════════════╪═══════╪═════════╪═══════════════╪═══╪═════════════╪══════╪══════════╪══════════════╡
# │ 7043        ┆ 7043  ┆ 7043    ┆ 7043          ┆ … ┆ 7043        ┆ 7043 ┆ 1869     ┆ 1869         │
# └─────────────┴───────┴─────────┴───────────────┴───┴─────────────┴──────┴──────────┴──────────────┘

# %%
df.describe()
# Out:
# shape: (9, 12)
# ┌────────────┬────────────┬────────┬─────────┬───┬────────────┬────────────┬───────────┬───────────┐
# │ statistic  ┆ Customer   ┆ Count  ┆ Quarter ┆ … ┆ Churn      ┆ CLTV       ┆ Churn     ┆ Churn     │
# │ ---        ┆ ID         ┆ ---    ┆ ---     ┆   ┆ Score      ┆ ---        ┆ Category  ┆ Reason    │
# │ str        ┆ ---        ┆ f64    ┆ str     ┆   ┆ ---        ┆ f64        ┆ ---       ┆ ---       │
# │            ┆ str        ┆        ┆         ┆   ┆ f64        ┆            ┆ str       ┆ str       │
# ╞════════════╪════════════╪════════╪═════════╪═══╪════════════╪════════════╪═══════════╪═══════════╡
# │ count      ┆ 7043       ┆ 7043.0 ┆ 7043    ┆ … ┆ 7043.0     ┆ 7043.0     ┆ 1869      ┆ 1869      │
# │ null_count ┆ 0          ┆ 0.0    ┆ 0       ┆ … ┆ 0.0        ┆ 0.0        ┆ 5174      ┆ 5174      │
# │ mean       ┆ null       ┆ 1.0    ┆ null    ┆ … ┆ 58.50504   ┆ 4400.29575 ┆ null      ┆ null      │
# │            ┆            ┆        ┆         ┆   ┆            ┆ 5          ┆           ┆           │
# │ std        ┆ null       ┆ 0.0    ┆ null    ┆ … ┆ 21.170031  ┆ 1183.05715 ┆ null      ┆ null      │
# │            ┆            ┆        ┆         ┆   ┆            ┆ 2          ┆           ┆           │
# │ min        ┆ 0002-ORFBO ┆ 1.0    ┆ Q3      ┆ … ┆ 5.0        ┆ 2003.0     ┆ Attitude  ┆ Attitude  │
# │            ┆            ┆        ┆         ┆   ┆            ┆            ┆           ┆ of        │
# │            ┆            ┆        ┆         ┆   ┆            ┆            ┆           ┆ service   │
# │            ┆            ┆        ┆         ┆   ┆            ┆            ┆           ┆ provider  │
# │ 25%        ┆ null       ┆ 1.0    ┆ null    ┆ … ┆ 40.0       ┆ 3469.0     ┆ null      ┆ null      │
# │ 50%        ┆ null       ┆ 1.0    ┆ null    ┆ … ┆ 61.0       ┆ 4527.0     ┆ null      ┆ null      │
# │ 75%        ┆ null       ┆ 1.0    ┆ null    ┆ … ┆ 76.0       ┆ 5381.0     ┆ null      ┆ null      │
# │ max        ┆ 9995-HOTOH ┆ 1.0    ┆ Q3      ┆ … ┆ 96.0       ┆ 6500.0     ┆ Price     ┆ Service   │
# │            ┆            ┆        ┆         ┆   ┆            ┆            ┆           ┆ dissatisf │
# │            ┆            ┆        ┆         ┆   ┆            ┆            ┆           ┆ action    │
# └────────────┴────────────┴────────┴─────────┴───┴────────────┴────────────┴───────────┴───────────┘

# %%
df.columns
# Out:
# ['Customer ID',
#  'Count',
#  'Quarter',
#  'Satisfaction Score',
#  'Customer Status',
#  'Churn Label',
#  'Churn Value',
#  'Churn Score',
#  'CLTV',
#  'Churn Category',
#  'Churn Reason']

# %%
df.group_by(pl.col('Customer ID')).len()
# Out:
# shape: (7_043, 2)
# ┌─────────────┬─────┐
# │ Customer ID ┆ len │
# │ ---         ┆ --- │
# │ str         ┆ u32 │
# ╞═════════════╪═════╡
# │ 5173-ZXXXL  ┆ 1   │
# │ 0794-YVSGE  ┆ 1   │
# │ 1043-YCUTE  ┆ 1   │
# │ 3230-IUALN  ┆ 1   │
# │ 6815-ABQFQ  ┆ 1   │
# │ …           ┆ …   │
# │ 4785-QRJHC  ┆ 1   │
# │ 0679-IDSTG  ┆ 1   │
# │ 8739-WWKDU  ┆ 1   │
# │ 8957-THMOA  ┆ 1   │
# │ 9025-AOMKI  ┆ 1   │
# └─────────────┴─────┘

# %%
df.group_by(pl.col('Count')).len()
# Out:
# shape: (1, 2)
# ┌───────┬──────┐
# │ Count ┆ len  │
# │ ---   ┆ ---  │
# │ i64   ┆ u32  │
# ╞═══════╪══════╡
# │ 1     ┆ 7043 │
# └───────┴──────┘

# %%
df.group_by(pl.col('Quarter')).len()
# Out:
# shape: (1, 2)
# ┌─────────┬──────┐
# │ Quarter ┆ len  │
# │ ---     ┆ ---  │
# │ str     ┆ u32  │
# ╞═════════╪══════╡
# │ Q3      ┆ 7043 │
# └─────────┴──────┘

# %%
df.group_by(pl.col('Satisfaction Score')).len()
# Out:
# shape: (5, 2)
# ┌────────────────────┬──────┐
# │ Satisfaction Score ┆ len  │
# │ ---                ┆ ---  │
# │ i64                ┆ u32  │
# ╞════════════════════╪══════╡
# │ 1                  ┆ 922  │
# │ 2                  ┆ 518  │
# │ 3                  ┆ 2665 │
# │ 4                  ┆ 1789 │
# │ 5                  ┆ 1149 │
# └────────────────────┴──────┘

# %%
df.group_by(pl.col('Customer Status')).len()
# Out:
# shape: (3, 2)
# ┌─────────────────┬──────┐
# │ Customer Status ┆ len  │
# │ ---             ┆ ---  │
# │ str             ┆ u32  │
# ╞═════════════════╪══════╡
# │ Churned         ┆ 1869 │
# │ Joined          ┆ 454  │
# │ Stayed          ┆ 4720 │
# └─────────────────┴──────┘

# %%
df.group_by(pl.col('Churn Label')).len()
# Out:
# shape: (2, 2)
# ┌─────────────┬──────┐
# │ Churn Label ┆ len  │
# │ ---         ┆ ---  │
# │ str         ┆ u32  │
# ╞═════════════╪══════╡
# │ No          ┆ 5174 │
# │ Yes         ┆ 1869 │
# └─────────────┴──────┘

# %%
df.group_by(pl.col('Churn Value')).len()
# Out:
# shape: (2, 2)
# ┌─────────────┬──────┐
# │ Churn Value ┆ len  │
# │ ---         ┆ ---  │
# │ i64         ┆ u32  │
# ╞═════════════╪══════╡
# │ 0           ┆ 5174 │
# │ 1           ┆ 1869 │
# └─────────────┴──────┘

# %%
df.group_by(pl.col('Churn Score')).len()
# Out:
# shape: (81, 2)
# ┌─────────────┬─────┐
# │ Churn Score ┆ len │
# │ ---         ┆ --- │
# │ i64         ┆ u32 │
# ╞═════════════╪═════╡
# │ 9           ┆ 3   │
# │ 21          ┆ 84  │
# │ 24          ┆ 86  │
# │ 42          ┆ 87  │
# │ 36          ┆ 72  │
# │ …           ┆ …   │
# │ 95          ┆ 46  │
# │ 86          ┆ 49  │
# │ 83          ┆ 59  │
# │ 89          ┆ 60  │
# │ 92          ┆ 51  │
# └─────────────┴─────┘

# %%
df.group_by(pl.col('CLTV')).len()
# Out:
# shape: (3_438, 2)
# ┌──────┬─────┐
# │ CLTV ┆ len │
# │ ---  ┆ --- │
# │ i64  ┆ u32 │
# ╞══════╪═════╡
# │ 3817 ┆ 2   │
# │ 2114 ┆ 1   │
# │ 4466 ┆ 2   │
# │ 4335 ┆ 3   │
# │ 4341 ┆ 1   │
# │ …    ┆ …   │
# │ 5761 ┆ 2   │
# │ 3007 ┆ 4   │
# │ 5237 ┆ 1   │
# │ 4451 ┆ 4   │
# │ 2078 ┆ 1   │
# └──────┴─────┘

# %%
df.group_by(pl.col('Churn Category')).len()
# Out:
# shape: (6, 2)
# ┌─────────────────┬──────┐
# │ Churn Category  ┆ len  │
# │ ---             ┆ ---  │
# │ str             ┆ u32  │
# ╞═════════════════╪══════╡
# │ Price           ┆ 211  │
# │ Other           ┆ 200  │
# │ Dissatisfaction ┆ 303  │
# │ Attitude        ┆ 314  │
# │ Competitor      ┆ 841  │
# │ null            ┆ 5174 │
# └─────────────────┴──────┘

# %%
df.group_by(pl.col('Churn Reason')).len()
# Out:
# shape: (21, 2)
# ┌─────────────────────────────────┬─────┐
# │ Churn Reason                    ┆ len │
# │ ---                             ┆ --- │
# │ str                             ┆ u32 │
# ╞═════════════════════════════════╪═════╡
# │ Product dissatisfaction         ┆ 77  │
# │ Deceased                        ┆ 6   │
# │ Long distance charges           ┆ 64  │
# │ Competitor had better devices   ┆ 313 │
# │ Price too high                  ┆ 78  │
# │ …                               ┆ …   │
# │ Lack of self-service on Websit… ┆ 29  │
# │ Attitude of service provider    ┆ 94  │
# │ Limited range of services       ┆ 37  │
# │ Moved                           ┆ 46  │
# │ Attitude of support person      ┆ 220 │
# └─────────────────────────────────┴─────┘

# %%
df.filter(pl.col('Churn Label')=='Yes'
        #   ,pl.col('Churn Reason').is_null()
          ,pl.col('Churn Category').is_null()
          )\
.group_by(['Churn Reason','Churn Category'])\
.len()
# Out:
# shape: (0, 3)
# ┌──────────────┬────────────────┬─────┐
# │ Churn Reason ┆ Churn Category ┆ len │
# │ ---          ┆ ---            ┆ --- │
# │ str          ┆ str            ┆ u32 │
# ╞══════════════╪════════════════╪═════╡
# └──────────────┴────────────────┴─────┘

# %%
df = df.with_columns(
    pl.col("Churn Category").fill_null("NO_LABEL")
    ,pl.col("Churn Reason").fill_null("NO_LABEL")
)

# %% [markdown]
# Conclusions:
# - Fiels 'Count' and 'Quarter' have only one value

# %%
df
# Out:
# shape: (7_043, 11)
# ┌─────────────┬───────┬─────────┬─────────────┬───┬─────────────┬──────┬─────────────┬─────────────┐
# │ Customer ID ┆ Count ┆ Quarter ┆ Satisfactio ┆ … ┆ Churn Score ┆ CLTV ┆ Churn       ┆ Churn       │
# │ ---         ┆ ---   ┆ ---     ┆ n Score     ┆   ┆ ---         ┆ ---  ┆ Category    ┆ Reason      │
# │ str         ┆ i64   ┆ str     ┆ ---         ┆   ┆ i64         ┆ i64  ┆ ---         ┆ ---         │
# │             ┆       ┆         ┆ i64         ┆   ┆             ┆      ┆ str         ┆ str         │
# ╞═════════════╪═══════╪═════════╪═════════════╪═══╪═════════════╪══════╪═════════════╪═════════════╡
# │ 8779-QRDMV  ┆ 1     ┆ Q3      ┆ 3           ┆ … ┆ 91          ┆ 5433 ┆ Competitor  ┆ Competitor  │
# │             ┆       ┆         ┆             ┆   ┆             ┆      ┆             ┆ offered     │
# │             ┆       ┆         ┆             ┆   ┆             ┆      ┆             ┆ more data   │
# │ 7495-OOKFY  ┆ 1     ┆ Q3      ┆ 3           ┆ … ┆ 69          ┆ 5302 ┆ Competitor  ┆ Competitor  │
# │             ┆       ┆         ┆             ┆   ┆             ┆      ┆             ┆ made better │
# │             ┆       ┆         ┆             ┆   ┆             ┆      ┆             ┆ offer       │
# │ 1658-BYGOY  ┆ 1     ┆ Q3      ┆ 2           ┆ … ┆ 81          ┆ 3179 ┆ Competitor  ┆ Competitor  │
# │             ┆       ┆         ┆             ┆   ┆             ┆      ┆             ┆ made better │
# │             ┆       ┆         ┆             ┆   ┆             ┆      ┆             ┆ offer       │
# │ 4598-XLKNJ  ┆ 1     ┆ Q3      ┆ 2           ┆ … ┆ 88          ┆ 5337 ┆ Dissatisfac ┆ Limited     │
# │             ┆       ┆         ┆             ┆   ┆             ┆      ┆ tion        ┆ range of    │
# │             ┆       ┆         ┆             ┆   ┆             ┆      ┆             ┆ services    │
# │ 4846-WHAFZ  ┆ 1     ┆ Q3      ┆ 2           ┆ … ┆ 67          ┆ 2793 ┆ Price       ┆ Extra data  │
# │             ┆       ┆         ┆             ┆   ┆             ┆      ┆             ┆ charges     │
# │ …           ┆ …     ┆ …       ┆ …           ┆ … ┆ …           ┆ …    ┆ …           ┆ …           │
# │ 2569-WGERO  ┆ 1     ┆ Q3      ┆ 5           ┆ … ┆ 45          ┆ 5306 ┆ NO_LABEL    ┆ NO_LABEL    │
# │ 6840-RESVB  ┆ 1     ┆ Q3      ┆ 3           ┆ … ┆ 59          ┆ 2140 ┆ NO_LABEL    ┆ NO_LABEL    │
# │ 2234-XADUH  ┆ 1     ┆ Q3      ┆ 4           ┆ … ┆ 71          ┆ 5560 ┆ NO_LABEL    ┆ NO_LABEL    │
# │ 4801-JZAZL  ┆ 1     ┆ Q3      ┆ 4           ┆ … ┆ 59          ┆ 2793 ┆ NO_LABEL    ┆ NO_LABEL    │
# │ 3186-AJIEK  ┆ 1     ┆ Q3      ┆ 4           ┆ … ┆ 38          ┆ 5097 ┆ NO_LABEL    ┆ NO_LABEL    │
# └─────────────┴───────┴─────────┴─────────────┴───┴─────────────┴──────┴─────────────┴─────────────┘
